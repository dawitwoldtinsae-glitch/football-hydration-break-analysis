# %%
import pandas as pd
from pathlib import Path

# %%
input_folder=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\12_22")
output_file=Path(r'C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\2026_12_22.csv')
files=input_folder.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file,index=False)

# %%
input_folder_1=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\25_35")
output_file_1=Path(r'C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\2026_25_35.csv')
files=input_folder_1.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file_1,index=False)

# %%
input_file_2=Path(r'C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\57_67')
output_file_2=Path(r'C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\2026_57_67.csv')
files=input_file_2.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file_2,index=False)

# %%
input_file_3=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\70_80")
output_file_3=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2026_cleaned\2026_70_80.csv")
files=input_file_3.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file_3,index=False)

# %%
input_file_4=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\12_22")
output_file_4=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\2022_12_22.csv")
files=input_file_4.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file_4,index=False)

# %%
input_file=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\22_32")
output_file=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\2022_22_32.csv")
files=input_file.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file,index=False)

# %%
input_file=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\57_67")
output_file=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\2022_57_67.csv")
files=input_file.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file,index=False)

# %%
input_file=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\67_77")
output_file=Path(r"C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\2022_67_77.csv")
files=input_file.glob('*.csv')
dataframes=[pd.read_csv(file) for file in files]
merged_data=pd.concat(dataframes,ignore_index=True)
merged_data.to_csv(output_file,index=False)

# %%
data=pd.read_csv(r'C:\Users\dawit\PycharmProjects\hydration break\data\2022_cleaned\2022')
